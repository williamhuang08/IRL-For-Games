# %%
# Importing data manipulation/visualization packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Import ML framework library
import torch as th
import torch.nn as nn
import torch.nn.init as init

# Importing gym packages
import gymnasium as gym
from gymnasium import spaces

# Importing IRL libraries
from stable_baselines3.ppo import MlpPolicy
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3 import PPO

# Importing imitation library
from imitation.algorithms.adversarial.airl import AIRL
from imitation.util import util
from imitation.data import rollout
from imitation.data.wrappers import RolloutInfoWrapper
from imitation.util.util import make_vec_env
from imitation.rewards.reward_nets import BasicShapedRewardNet
from imitation.rewards.reward_nets import RewardNet
from imitation.util.networks import RunningNorm
from imitation.util import networks, util

# Import miscellaneuous packages
import random
from scipy.stats import norm

# %%
# Setting the seed
SEED = 42
np.random.seed(SEED)
th.manual_seed(SEED)
if th.cuda.is_available():
    th.cuda.manual_seed_all(SEED)

# %%
# Arbitrary weights for the importance of the engagement level and section number
a, b = 1, 0.5

# Arbitary thresholds for what to what scores should be considered extremely interested, mildy interested, and not interested
theta_1 = 0.9
theta_2 = 0.4

# Define actions
ACTION_WAIT = 0
ACTION_READ_FREE = 1
ACTION_READ_PAY = 2

# Number of chapters
NUM_CHAPTERS = 24

# %%
# Helper function to calculate how interested an agent is
def interest_score (engagement_level, section_number):
    """
    Calculates a metric to gauge engagement using state feature information.
    :param options: Engagement level and the section number (chapter number)
    :return: Calculated score
    """
    norm_section_number = (section_number - 1) / (NUM_CHAPTERS - 1)
    return a * engagement_level + b * norm_section_number

# %%
# Helper function to draw from Bernoulli (in my case, want to draw to choose between 2 values)
def probabilistic_choice(options):
    """
    Chooses an action probabilistically based on weights.
    :param options: List of (action, probability) tuples
    :return: Chosen action
    """
    actions, probabilities = zip(*options)
    return random.choices(actions, weights=probabilities, k=1)[0]

# %%
class ExpertPolicy:
	def __call__ (self, state, obs, dones=None, infos=None):
		"""
		Maps a state to an action.
		:param options: A list of states containing lists of state features [section_number, engagement_level, time, price]
		:return: Action
		"""	
		state = state[0] # Since we are only using 1 environment in the vectorized env so the batch size is 1
		section_number, engagement_level, time, price = state

		score = interest_score(engagement_level, section_number)

		if score > theta_1:
			if price == 1:
				action = probabilistic_choice([(ACTION_READ_PAY, 0.7), (ACTION_WAIT, 0.3)])
			else:
				action = probabilistic_choice([(ACTION_READ_FREE, 0.9), (ACTION_WAIT, 0.1)])
		elif theta_2 < score < theta_1:
			if time < 24: # time interval since last read is short
				if price == 1:
					action = probabilistic_choice([(ACTION_READ_PAY, 0.5), (ACTION_WAIT, 0.5)])
				else:
					action = probabilistic_choice([(ACTION_READ_FREE, 0.7), (ACTION_WAIT, 0.3)])
			else: # time interval since last read is long (reader is less engaged)
				if price == 1:
					action = probabilistic_choice([(ACTION_READ_PAY, 0.3), (ACTION_WAIT, 0.7)])
				else:
					action = probabilistic_choice([(ACTION_READ_FREE, 0.5), (ACTION_WAIT, 0.5)])			
		else:
			if time < 36: # time interval since last read is short
				if price == 1:
					action = probabilistic_choice([(ACTION_READ_PAY, 0.2), (ACTION_WAIT, 0.8)])
				else:
					action = probabilistic_choice([(ACTION_READ_FREE, 0.4), (ACTION_WAIT, 0.6)])
			else: # time interval since last read is long (reader is less engaged)
				if price == 1:
					action = probabilistic_choice([(ACTION_READ_PAY, 0.1), (ACTION_WAIT, 0.9)])
				else:
					action = probabilistic_choice([(ACTION_READ_FREE, 0.2), (ACTION_WAIT, 0.8)])
		return [action], None

# %%
def true_reward (state, action):
	"""
	The true reward function that maps a (state, action) pair to a real number.
	:param options: A state feature list [section_number, engagement_level, time, price], and an action
	:return: A real number (the reward)
	"""	
	
	section_number, engagement_level, time, price = state
	score = interest_score(engagement_level, section_number)
	
	if score > theta_1:
		if price == 1:
			if action == ACTION_READ_PAY:
				return 5
			else: # Wait
				return -1
		if price == 0:
			if action == ACTION_READ_FREE:
				return 9
			else: # Wait
				return -1
	elif theta_2 < score < theta_1:
		if time < 24: # time interval since last read is short
			if price == 1:
				if action == ACTION_READ_PAY:
					return 4
				else: # Wait
					return -1
			if price == 0:
				if action == ACTION_READ_FREE:
					return 7
				else: # Wait
					return -1
		else: # time interval since last read is long (reader is less engaged)
			if price == 1:
				if action == ACTION_READ_PAY:
					return 3
				else: # Wait
					return -1
			if price == 0:
				if action == ACTION_READ_FREE:
					return 6
				else: # Wait
					return -1
	else:
		if time < 36: # time interval since last read is short
			if price == 1:
				if action == ACTION_READ_PAY:
					return 2
				else: # Wait
					return -1
			if price == 0:
				if action == ACTION_READ_FREE:
					return 5
				else: # Wait
					return -1
		else: # time interval since last read is long (reader is less engaged)
			if price == 1:
				if action == ACTION_READ_PAY:
					return 1
				else: # Wait
					return -1
			if price == 0:
				if ACTION_READ_FREE:
					return 3
				else: # Wait
					return -1

# %%
class EBookEnv(gym.Env):
    def __init__(self):
        super(EBookEnv).__init__()

        # state =  [section_number, engagement_level, time, price]
        self.observation_space = spaces.Box(low=0, high=1, shape=(4,), dtype=np.float32)

        # action = [wait, read_without_payment, read_with_payment]
        self.action_space = spaces.Discrete(3)

        self.state = None
        self.times_bought = 0

    def reset(self, seed=None, options=None):
        # Resetting the state so that the reader begins at section 1, at a 0.8 engagement level, time 0, and price 0
        self.state = np.array([1, 0.8, 0, 0], dtype=np.float32)
        self.times_bought = 0
        return self.state, {}

    def step(self, action):
        # Calculate the reward
        reward = true_reward(self.state, action)

        section_number, engagement_level, time, price = self.state

        """ *** Update the state features *** """
        if action == ACTION_READ_PAY or action == ACTION_READ_FREE: # Section number only increases if the current action is to read (pay or not pay)
            section_number += 1
            time = 0 # Reset the time because the new time interval starts at beginning of chapters

        # Update the number of times a chapter was bought
        if action == ACTION_READ_PAY:
            self.times_bought += 1

        gamma = 0.7 # parameter to change probability of price being a 1
        if section_number < 4: # Ensure that the first 4 sections are free
            price = 0
        else:
            price = probabilistic_choice([(1, 1 - gamma ** section_number), (0, gamma ** section_number)])
        
        time += 1 # Time is always incremented
        engagement_level = norm.cdf(np.random.normal(0, 1)) # Draw the engagement index from a N~(0, 1) and normalize to [0, 1]

        # Save the new state
        self.state = np.array([section_number, engagement_level, time, price], dtype=np.float32)

        # The terminating condition is when you reach the end of a book or if the time interval gets very large
        done = time >= 108 or section_number > NUM_CHAPTERS

        if done:
            print(f"Agent bought chapters {self.times_bought} times")
        truncated = False
        info = {"obs": self.state, "rews": reward}
        return self.state, float(reward), done, truncated, info

    def render(self, mode='human'):
        pass

# %%
# Register the gym for compatability with OpenAI Gym
gym.register(id='EBookEnv-v0', entry_point=lambda: EBookEnv())
venv = util.make_vec_env("EBookEnv-v0", rng=np.random.default_rng(SEED), n_envs=1, post_wrappers=[lambda env, _: RolloutInfoWrapper(env)])
# Out:
# /Users/williamhuang/anaconda3/envs/tobin/lib/python3.9/site-packages/gymnasium/envs/registration.py:694: UserWarning: WARN: Overriding environment EBookEnv-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")

# %%
# Collect 500 trajectories of the expert behavior 
expert_policy = ExpertPolicy()
trajectories = rollout.rollout(
    expert_policy,
    venv,
    rollout.make_sample_until(min_episodes=500),
    rng=np.random.default_rng(SEED),
)
# Out:
# /Users/williamhuang/anaconda3/envs/tobin/lib/python3.9/site-packages/gymnasium/utils/passive_env_checker.py:159: UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 18 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 18 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 18 times
# Agent bought chapters 18 times
# Agent bought chapters 20 times
# Agent bought chapters 18 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 19 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 17 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 18 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 18 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 18 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 17 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 18 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 18 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 17 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 18 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 18 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 18 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 18 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 18 times
# Agent bought chapters 20 times
# Agent bought chapters 18 times
# Agent bought chapters 19 times
# Agent bought chapters 18 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 18 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 18 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 19 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 18 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 19 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 18 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 18 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 18 times
# Agent bought chapters 19 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 18 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 19 times
# Agent bought chapters 17 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 18 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 18 times
# Agent bought chapters 19 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 18 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 18 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 18 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 18 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 18 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 18 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 18 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 19 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times
# Agent bought chapters 21 times

# %%
"""
    Initialize a PPO agent to interact with the environment. 
    In AIRL, the learner is the generator. The model will try to imitate expert behavior by 
    having the discriminator distinguish between trajectories generated between the PPO agent
    and the true trajectories from the expert policy defined above.
"""
learner = PPO(
    env=venv,
    policy=MlpPolicy,
    batch_size=64,
    ent_coef=0.0,
    learning_rate=0.0005,
    gamma=0.95,
    clip_range=0.1,
    vf_coef=0.1,
    n_epochs=5,
    seed=SEED,
)

"""
    Initialize a reward network. 
"""
reward_net = BasicShapedRewardNet(
    observation_space=venv.observation_space,
    action_space=venv.action_space,
    normalize_input_layer=RunningNorm,
)

# Intialize parameters for AIRL model
airl_trainer = AIRL(
    demonstrations=trajectories,
    demo_batch_size=2048,
    gen_replay_buffer_capacity=512,
    n_disc_updates_per_round=16,
    venv=venv,
    gen_algo=learner,
    reward_net=reward_net,
    allow_variable_horizon=True
)
# Out:
# Running with `allow_variable_horizon` set to True. Some algorithms are biased towards shorter or longer episodes, which may significantly confound results. Additionally, even unbiased algorithms can exploit the information leak from the termination condition, producing spuriously high performance. See https://imitation.readthedocs.io/en/latest/getting-started/variable-horizon.html for more information.

# %%
venv.seed(SEED)

airl_trainer.train(20000)  # Train for 2_000_000 steps to match expert by learning a reward and a policy
# Out:
# round:   0%|          | 0/9 [00:00<?, ?it/s]
# Agent bought chapters 14 times
# Agent bought chapters 9 times
# Agent bought chapters 8 times
# Agent bought chapters 7 times
# Agent bought chapters 12 times
# Agent bought chapters 12 times
# Agent bought chapters 14 times
# Agent bought chapters 13 times
# Agent bought chapters 11 times
# Agent bought chapters 15 times
# Agent bought chapters 13 times
# Agent bought chapters 13 times
# Agent bought chapters 13 times
# Agent bought chapters 12 times
# Agent bought chapters 14 times
# Agent bought chapters 14 times
# Agent bought chapters 17 times
# Agent bought chapters 13 times
# Agent bought chapters 11 times
# Agent bought chapters 11 times
# Agent bought chapters 13 times
# Agent bought chapters 12 times
# Agent bought chapters 12 times
# Agent bought chapters 6 times
# Agent bought chapters 12 times
# Agent bought chapters 12 times
# Agent bought chapters 10 times
# Agent bought chapters 10 times
# Agent bought chapters 13 times
# Agent bought chapters 9 times
# Agent bought chapters 11 times
# Agent bought chapters 12 times
# Agent bought chapters 12 times
# Agent bought chapters 13 times
# Agent bought chapters 16 times
# Agent bought chapters 9 times
# Agent bought chapters 7 times
# Agent bought chapters 13 times
# Agent bought chapters 10 times
# Agent bought chapters 9 times
# Agent bought chapters 12 times
# Agent bought chapters 14 times
# Agent bought chapters 12 times
# Agent bought chapters 13 times
# Agent bought chapters 13 times
# Agent bought chapters 12 times
# Agent bought chapters 12 times
# Agent bought chapters 15 times
# Agent bought chapters 11 times
# Agent bought chapters 13 times
# Agent bought chapters 9 times
# Agent bought chapters 9 times
# Agent bought chapters 13 times
# Agent bought chapters 9 times
# Agent bought chapters 12 times
# Agent bought chapters 10 times
# ------------------------------------------
# | raw/                        |          |
# |    gen/rollout/ep_len_mean  | 35.9     |
# |    gen/rollout/ep_rew_mean  | 31.9     |
# |    gen/time/fps             | 1934     |
# |    gen/time/iterations      | 1        |
# |    gen/time/time_elapsed    | 1        |
# |    gen/time/total_timesteps | 2048     |
# ------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.594    |
# |    disc/disc_loss                   | 0.802    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.596    |
# |    disc/disc_loss                   | 0.798    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.598    |
# |    disc/disc_loss                   | 0.799    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.601    |
# |    disc/disc_loss                   | 0.794    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.603    |
# |    disc/disc_loss                   | 0.793    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.604    |
# |    disc/disc_loss                   | 0.791    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.608    |
# |    disc/disc_loss                   | 0.786    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.609    |
# |    disc/disc_loss                   | 0.782    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.612    |
# |    disc/disc_loss                   | 0.78     |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.614    |
# |    disc/disc_loss                   | 0.777    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.616    |
# |    disc/disc_loss                   | 0.776    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.618    |
# |    disc/disc_loss                   | 0.774    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.619    |
# |    disc/disc_loss                   | 0.77     |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.621    |
# |    disc/disc_loss                   | 0.765    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.623    |
# |    disc/disc_loss                   | 0.764    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.625    |
# |    disc/disc_loss                   | 0.763    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.61     |
# |    disc/disc_loss                   | 0.782    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# |    gen/rollout/ep_len_mean          | 35.9     |
# |    gen/rollout/ep_rew_mean          | 31.9     |
# |    gen/time/fps                     | 1.93e+03 |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 1        |
# |    gen/time/total_timesteps         | 2.05e+03 |
# |    gen/train/approx_kl              | 0.00274  |
# |    gen/train/clip_fraction          | 0.117    |
# |    gen/train/clip_range             | 0.1      |
# |    gen/train/entropy_loss           | -1.1     |
# |    gen/train/explained_variance     | -0.179   |
# |    gen/train/learning_rate          | 0.0005   |
# |    gen/train/loss                   | 0.0405   |
# |    gen/train/n_updates              | 5        |
# |    gen/train/policy_gradient_loss   | -0.00684 |
# |    gen/train/value_loss             | 0.942    |
# --------------------------------------------------
# round:  11%|█         | 1/9 [00:02<00:17,  2.24s/it]
# Agent bought chapters 14 times
# Agent bought chapters 12 times
# Agent bought chapters 13 times
# Agent bought chapters 14 times
# Agent bought chapters 11 times
# Agent bought chapters 14 times
# Agent bought chapters 15 times
# Agent bought chapters 11 times
# Agent bought chapters 12 times
# Agent bought chapters 9 times
# Agent bought chapters 14 times
# Agent bought chapters 10 times
# Agent bought chapters 16 times
# Agent bought chapters 13 times
# Agent bought chapters 10 times
# Agent bought chapters 9 times
# Agent bought chapters 13 times
# Agent bought chapters 13 times
# Agent bought chapters 8 times
# Agent bought chapters 15 times
# Agent bought chapters 16 times
# Agent bought chapters 13 times
# Agent bought chapters 12 times
# Agent bought chapters 9 times
# Agent bought chapters 12 times
# Agent bought chapters 9 times
# Agent bought chapters 7 times
# Agent bought chapters 9 times
# Agent bought chapters 13 times
# Agent bought chapters 7 times
# Agent bought chapters 10 times
# Agent bought chapters 15 times
# Agent bought chapters 9 times
# Agent bought chapters 13 times
# Agent bought chapters 14 times
# Agent bought chapters 13 times
# Agent bought chapters 10 times
# Agent bought chapters 9 times
# Agent bought chapters 14 times
# Agent bought chapters 10 times
# Agent bought chapters 14 times
# Agent bought chapters 13 times
# Agent bought chapters 10 times
# Agent bought chapters 12 times
# Agent bought chapters 13 times
# Agent bought chapters 13 times
# Agent bought chapters 11 times
# Agent bought chapters 10 times
# Agent bought chapters 12 times
# Agent bought chapters 13 times
# Agent bought chapters 12 times
# Agent bought chapters 14 times
# Agent bought chapters 13 times
# Agent bought chapters 11 times
# Agent bought chapters 12 times
# Agent bought chapters 11 times
# Agent bought chapters 11 times
# Agent bought chapters 10 times
# Agent bought chapters 10 times
# Agent bought chapters 10 times
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 35          |
# |    gen/rollout/ep_rew_mean         | 30.4        |
# |    gen/rollout/ep_rew_wrapped_mean | -10.9       |
# |    gen/time/fps                    | 1839        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 1           |
# |    gen/time/total_timesteps        | 4096        |
# |    gen/train/approx_kl             | 0.002735389 |
# |    gen/train/clip_fraction         | 0.117       |
# |    gen/train/clip_range            | 0.1         |
# |    gen/train/entropy_loss          | -1.1        |
# |    gen/train/explained_variance    | -0.179      |
# |    gen/train/learning_rate         | 0.0005      |
# |    gen/train/loss                  | 0.0405      |
# |    gen/train/n_updates             | 5           |
# |    gen/train/policy_gradient_loss  | -0.00684    |
# |    gen/train/value_loss            | 0.942       |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.623    |
# |    disc/disc_loss                   | 0.753    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.625    |
# |    disc/disc_loss                   | 0.75     |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.627    |
# |    disc/disc_loss                   | 0.749    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.628    |
# |    disc/disc_loss                   | 0.746    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.631    |
# |    disc/disc_loss                   | 0.745    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.633    |
# |    disc/disc_loss                   | 0.74     |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.633    |
# |    disc/disc_loss                   | 0.738    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.634    |
# |    disc/disc_loss                   | 0.739    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.636    |
# |    disc/disc_loss                   | 0.736    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0.999    |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.638    |
# |    disc/disc_loss                   | 0.734    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.639    |
# |    disc/disc_loss                   | 0.729    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.641    |
# |    disc/disc_loss                   | 0.732    |
# |    disc/disc_proportion_expert_pred | 1        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0.998    |
# |    disc/disc_acc_gen                | 0.000977 |
# |    disc/disc_entropy                | 0.642    |
# |    disc/disc_loss                   | 0.724    |
# |    disc/disc_proportion_expert_pred | 0.999    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0.999    |
# |    disc/disc_acc_gen                | 0.00195  |
# |    disc/disc_entropy                | 0.643    |
# |    disc/disc_loss                   | 0.723    |
# |    disc/disc_proportion_expert_pred | 0.999    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0.998    |
# |    disc/disc_acc_gen                | 0.00195  |
# |    disc/disc_entropy                | 0.646    |
# |    disc/disc_loss                   | 0.723    |
# |    disc/disc_proportion_expert_pred | 0.998    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.501    |
# |    disc/disc_acc_expert             | 0.997    |
# |    disc/disc_acc_gen                | 0.00488  |
# |    disc/disc_entropy                | 0.646    |
# |    disc/disc_loss                   | 0.719    |
# |    disc/disc_proportion_expert_pred | 0.996    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0.999    |
# |    disc/disc_acc_gen                | 0.00061  |
# |    disc/disc_entropy                | 0.635    |
# |    disc/disc_loss                   | 0.736    |
# |    disc/disc_proportion_expert_pred | 0.999    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# |    gen/rollout/ep_len_mean          | 35       |
# |    gen/rollout/ep_rew_mean          | 30.4     |
# |    gen/rollout/ep_rew_wrapped_mean  | -10.9    |
# |    gen/time/fps                     | 1.84e+03 |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 1        |
# |    gen/time/total_timesteps         | 4.1e+03  |
# |    gen/train/approx_kl              | 0.00651  |
# |    gen/train/clip_fraction          | 0.259    |
# |    gen/train/clip_range             | 0.1      |
# |    gen/train/entropy_loss           | -1.08    |
# |    gen/train/explained_variance     | -0.248   |
# |    gen/train/learning_rate          | 0.0005   |
# |    gen/train/loss                   | 0.0399   |
# |    gen/train/n_updates              | 10       |
# |    gen/train/policy_gradient_loss   | -0.0103  |
# |    gen/train/value_loss             | 0.815    |
# --------------------------------------------------
# round:  22%|██▏       | 2/9 [00:03<00:13,  1.95s/it]
# Agent bought chapters 11 times
# Agent bought chapters 15 times
# Agent bought chapters 10 times
# Agent bought chapters 14 times
# Agent bought chapters 10 times
# Agent bought chapters 13 times
# Agent bought chapters 10 times
# Agent bought chapters 12 times
# Agent bought chapters 11 times
# Agent bought chapters 13 times
# Agent bought chapters 14 times
# Agent bought chapters 11 times
# Agent bought chapters 10 times
# Agent bought chapters 14 times
# Agent bought chapters 7 times
# Agent bought chapters 11 times
# Agent bought chapters 11 times
# Agent bought chapters 11 times
# Agent bought chapters 11 times
# Agent bought chapters 10 times
# Agent bought chapters 12 times
# Agent bought chapters 8 times
# Agent bought chapters 12 times
# Agent bought chapters 9 times
# Agent bought chapters 10 times
# Agent bought chapters 11 times
# Agent bought chapters 8 times
# Agent bought chapters 11 times
# Agent bought chapters 7 times
# Agent bought chapters 11 times
# Agent bought chapters 12 times
# Agent bought chapters 16 times
# Agent bought chapters 10 times
# Agent bought chapters 10 times
# Agent bought chapters 13 times
# Agent bought chapters 13 times
# Agent bought chapters 9 times
# Agent bought chapters 11 times
# Agent bought chapters 11 times
# Agent bought chapters 16 times
# Agent bought chapters 13 times
# Agent bought chapters 14 times
# Agent bought chapters 14 times
# Agent bought chapters 13 times
# Agent bought chapters 13 times
# Agent bought chapters 12 times
# Agent bought chapters 15 times
# Agent bought chapters 12 times
# Agent bought chapters 13 times
# Agent bought chapters 12 times
# Agent bought chapters 10 times
# Agent bought chapters 14 times
# Agent bought chapters 11 times
# Agent bought chapters 12 times
# Agent bought chapters 13 times
# Agent bought chapters 10 times
# Agent bought chapters 11 times
# Agent bought chapters 15 times
# Agent bought chapters 9 times
# Agent bought chapters 13 times
# Agent bought chapters 16 times
# Agent bought chapters 13 times
# Agent bought chapters 12 times
# Agent bought chapters 13 times
# -----------------------------------------------------
# | raw/                               |              |
# |    gen/rollout/ep_len_mean         | 33.2         |
# |    gen/rollout/ep_rew_mean         | 34.2         |
# |    gen/rollout/ep_rew_wrapped_mean | -11.8        |
# |    gen/time/fps                    | 1832         |
# |    gen/time/iterations             | 1            |
# |    gen/time/time_elapsed           | 1            |
# |    gen/time/total_timesteps        | 6144         |
# |    gen/train/approx_kl             | 0.0065076062 |
# |    gen/train/clip_fraction         | 0.259        |
# |    gen/train/clip_range            | 0.1          |
# |    gen/train/entropy_loss          | -1.08        |
# |    gen/train/explained_variance    | -0.248       |
# |    gen/train/learning_rate         | 0.0005       |
# |    gen/train/loss                  | 0.0399       |
# |    gen/train/n_updates             | 10           |
# |    gen/train/policy_gradient_loss  | -0.0103      |
# |    gen/train/value_loss            | 0.815        |
# -----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.499    |
# |    disc/disc_acc_expert             | 0.998    |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.638    |
# |    disc/disc_loss                   | 0.72     |
# |    disc/disc_proportion_expert_pred | 0.999    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.499    |
# |    disc/disc_acc_expert             | 0.997    |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.64     |
# |    disc/disc_loss                   | 0.719    |
# |    disc/disc_proportion_expert_pred | 0.999    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.498    |
# |    disc/disc_acc_expert             | 0.995    |
# |    disc/disc_acc_gen                | 0.000488 |
# |    disc/disc_entropy                | 0.639    |
# |    disc/disc_loss                   | 0.717    |
# |    disc/disc_proportion_expert_pred | 0.997    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.498    |
# |    disc/disc_acc_expert             | 0.997    |
# |    disc/disc_acc_gen                | 0        |
# |    disc/disc_entropy                | 0.642    |
# |    disc/disc_loss                   | 0.714    |
# |    disc/disc_proportion_expert_pred | 0.998    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.501    |
# |    disc/disc_acc_expert             | 0.992    |
# |    disc/disc_acc_gen                | 0.0107   |
# |    disc/disc_entropy                | 0.643    |
# |    disc/disc_loss                   | 0.716    |
# |    disc/disc_proportion_expert_pred | 0.99     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.498    |
# |    disc/disc_acc_expert             | 0.987    |
# |    disc/disc_acc_gen                | 0.00977  |
# |    disc/disc_entropy                | 0.645    |
# |    disc/disc_loss                   | 0.714    |
# |    disc/disc_proportion_expert_pred | 0.989    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0.988    |
# |    disc/disc_acc_gen                | 0.0117   |
# |    disc/disc_entropy                | 0.645    |
# |    disc/disc_loss                   | 0.709    |
# |    disc/disc_proportion_expert_pred | 0.988    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.499    |
# |    disc/disc_acc_expert             | 0.985    |
# |    disc/disc_acc_gen                | 0.0137   |
# |    disc/disc_entropy                | 0.648    |
# |    disc/disc_loss                   | 0.706    |
# |    disc/disc_proportion_expert_pred | 0.986    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.506    |
# |    disc/disc_acc_expert             | 0.985    |
# |    disc/disc_acc_gen                | 0.0278   |
# |    disc/disc_entropy                | 0.647    |
# |    disc/disc_loss                   | 0.707    |
# |    disc/disc_proportion_expert_pred | 0.979    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0.97     |
# |    disc/disc_acc_gen                | 0.0298   |
# |    disc/disc_entropy                | 0.65     |
# |    disc/disc_loss                   | 0.701    |
# |    disc/disc_proportion_expert_pred | 0.97     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.506    |
# |    disc/disc_acc_expert             | 0.978    |
# |    disc/disc_acc_gen                | 0.0347   |
# |    disc/disc_entropy                | 0.65     |
# |    disc/disc_loss                   | 0.698    |
# |    disc/disc_proportion_expert_pred | 0.972    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0.963    |
# |    disc/disc_acc_gen                | 0.0371   |
# |    disc/disc_entropy                | 0.651    |
# |    disc/disc_loss                   | 0.701    |
# |    disc/disc_proportion_expert_pred | 0.963    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.497    |
# |    disc/disc_acc_expert             | 0.958    |
# |    disc/disc_acc_gen                | 0.0352   |
# |    disc/disc_entropy                | 0.652    |
# |    disc/disc_loss                   | 0.7      |
# |    disc/disc_proportion_expert_pred | 0.961    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.505    |
# |    disc/disc_acc_expert             | 0.959    |
# |    disc/disc_acc_gen                | 0.0508   |
# |    disc/disc_entropy                | 0.653    |
# |    disc/disc_loss                   | 0.695    |
# |    disc/disc_proportion_expert_pred | 0.954    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.502    |
# |    disc/disc_acc_expert             | 0.955    |
# |    disc/disc_acc_gen                | 0.0503   |
# |    disc/disc_entropy                | 0.654    |
# |    disc/disc_loss                   | 0.69     |
# |    disc/disc_proportion_expert_pred | 0.952    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.496    |
# |    disc/disc_acc_expert             | 0.941    |
# |    disc/disc_acc_gen                | 0.0513   |
# |    disc/disc_entropy                | 0.655    |
# |    disc/disc_loss                   | 0.698    |
# |    disc/disc_proportion_expert_pred | 0.945    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0.978    |
# |    disc/disc_acc_gen                | 0.0227   |
# |    disc/disc_entropy                | 0.647    |
# |    disc/disc_loss                   | 0.706    |
# |    disc/disc_proportion_expert_pred | 0.978    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# |    gen/rollout/ep_len_mean          | 33.2     |
# |    gen/rollout/ep_rew_mean          | 34.2     |
# |    gen/rollout/ep_rew_wrapped_mean  | -11.8    |
# |    gen/time/fps                     | 1.83e+03 |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 1        |
# |    gen/time/total_timesteps         | 6.14e+03 |
# |    gen/train/approx_kl              | 0.0101   |
# |    gen/train/clip_fraction          | 0.282    |
# |    gen/train/clip_range             | 0.1      |
# |    gen/train/entropy_loss           | -1.05    |
# |    gen/train/explained_variance     | 0.71     |
# |    gen/train/learning_rate          | 0.0005   |
# |    gen/train/loss                   | 0.0175   |
# |    gen/train/n_updates              | 15       |
# |    gen/train/policy_gradient_loss   | -0.0146  |
# |    gen/train/value_loss             | 0.741    |
# --------------------------------------------------
# round:  33%|███▎      | 3/9 [00:05<00:11,  1.93s/it]
# Agent bought chapters 7 times
# Agent bought chapters 17 times
# Agent bought chapters 13 times
# Agent bought chapters 13 times
# Agent bought chapters 11 times
# Agent bought chapters 11 times
# Agent bought chapters 12 times
# Agent bought chapters 9 times
# Agent bought chapters 15 times
# Agent bought chapters 13 times
# Agent bought chapters 13 times
# Agent bought chapters 7 times
# Agent bought chapters 8 times
# Agent bought chapters 14 times
# Agent bought chapters 9 times
# Agent bought chapters 14 times
# Agent bought chapters 17 times
# Agent bought chapters 6 times
# Agent bought chapters 12 times
# Agent bought chapters 16 times
# Agent bought chapters 13 times
# Agent bought chapters 16 times
# Agent bought chapters 14 times
# Agent bought chapters 8 times
# Agent bought chapters 9 times
# Agent bought chapters 12 times
# Agent bought chapters 9 times
# Agent bought chapters 14 times
# Agent bought chapters 9 times
# Agent bought chapters 12 times
# Agent bought chapters 12 times
# Agent bought chapters 15 times
# Agent bought chapters 13 times
# Agent bought chapters 11 times
# Agent bought chapters 10 times
# Agent bought chapters 12 times
# Agent bought chapters 11 times
# Agent bought chapters 13 times
# Agent bought chapters 10 times
# Agent bought chapters 16 times
# Agent bought chapters 11 times
# Agent bought chapters 13 times
# Agent bought chapters 9 times
# Agent bought chapters 12 times
# Agent bought chapters 12 times
# Agent bought chapters 11 times
# Agent bought chapters 12 times
# Agent bought chapters 12 times
# Agent bought chapters 15 times
# Agent bought chapters 9 times
# Agent bought chapters 18 times
# Agent bought chapters 11 times
# Agent bought chapters 9 times
# Agent bought chapters 8 times
# Agent bought chapters 13 times
# Agent bought chapters 11 times
# Agent bought chapters 12 times
# Agent bought chapters 10 times
# Agent bought chapters 17 times
# Agent bought chapters 13 times
# Agent bought chapters 10 times
# Agent bought chapters 9 times
# Agent bought chapters 12 times
# Agent bought chapters 12 times
# Agent bought chapters 12 times
# Agent bought chapters 11 times
# Agent bought chapters 9 times
# Agent bought chapters 14 times
# Agent bought chapters 11 times
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 30.5        |
# |    gen/rollout/ep_rew_mean         | 37.6        |
# |    gen/rollout/ep_rew_wrapped_mean | -15.6       |
# |    gen/time/fps                    | 1819        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 1           |
# |    gen/time/total_timesteps        | 8192        |
# |    gen/train/approx_kl             | 0.010050051 |
# |    gen/train/clip_fraction         | 0.282       |
# |    gen/train/clip_range            | 0.1         |
# |    gen/train/entropy_loss          | -1.05       |
# |    gen/train/explained_variance    | 0.71        |
# |    gen/train/learning_rate         | 0.0005      |
# |    gen/train/loss                  | 0.0175      |
# |    gen/train/n_updates             | 15          |
# |    gen/train/policy_gradient_loss  | -0.0146     |
# |    gen/train/value_loss            | 0.741       |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.549    |
# ...
# |    gen/train/loss                   | 0.0421   |
# |    gen/train/n_updates              | 40       |
# |    gen/train/policy_gradient_loss   | -0.0278  |
# |    gen/train/value_loss             | 1.1      |
# --------------------------------------------------
# round:  89%|████████▉ | 8/9 [00:14<00:01,  1.85s/it]
# Agent bought chapters 20 times
# Agent bought chapters 16 times
# Agent bought chapters 19 times
# Agent bought chapters 18 times
# Agent bought chapters 19 times
# Agent bought chapters 20 times
# Agent bought chapters 16 times
# Agent bought chapters 19 times
# Agent bought chapters 17 times
# Agent bought chapters 15 times
# Agent bought chapters 20 times
# Agent bought chapters 17 times
# Agent bought chapters 17 times
# Agent bought chapters 16 times
# Agent bought chapters 13 times
# Agent bought chapters 16 times
# Agent bought chapters 19 times
# Agent bought chapters 15 times
# Agent bought chapters 20 times
# Agent bought chapters 15 times
# Agent bought chapters 15 times
# Agent bought chapters 15 times
# Agent bought chapters 19 times
# Agent bought chapters 18 times
# Agent bought chapters 17 times
# Agent bought chapters 15 times
# Agent bought chapters 20 times
# Agent bought chapters 21 times
# Agent bought chapters 17 times
# Agent bought chapters 16 times
# Agent bought chapters 14 times
# Agent bought chapters 16 times
# Agent bought chapters 20 times
# Agent bought chapters 17 times
# Agent bought chapters 17 times
# Agent bought chapters 16 times
# Agent bought chapters 18 times
# Agent bought chapters 12 times
# Agent bought chapters 21 times
# Agent bought chapters 20 times
# Agent bought chapters 15 times
# Agent bought chapters 16 times
# Agent bought chapters 19 times
# Agent bought chapters 16 times
# Agent bought chapters 17 times
# Agent bought chapters 17 times
# Agent bought chapters 12 times
# Agent bought chapters 15 times
# Agent bought chapters 16 times
# Agent bought chapters 20 times
# Agent bought chapters 14 times
# Agent bought chapters 17 times
# Agent bought chapters 14 times
# Agent bought chapters 19 times
# Agent bought chapters 16 times
# Agent bought chapters 16 times
# Agent bought chapters 17 times
# Agent bought chapters 20 times
# Agent bought chapters 16 times
# Agent bought chapters 17 times
# Agent bought chapters 17 times
# Agent bought chapters 17 times
# Agent bought chapters 17 times
# Agent bought chapters 19 times
# Agent bought chapters 21 times
# Agent bought chapters 17 times
# Agent bought chapters 15 times
# Agent bought chapters 16 times
# Agent bought chapters 17 times
# Agent bought chapters 17 times
# Agent bought chapters 11 times
# Agent bought chapters 20 times
# Agent bought chapters 19 times
# Agent bought chapters 15 times
# Agent bought chapters 22 times
# Agent bought chapters 13 times
# Agent bought chapters 16 times
# Agent bought chapters 18 times
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 26.2        |
# |    gen/rollout/ep_rew_mean         | 56.5        |
# |    gen/rollout/ep_rew_wrapped_mean | -32.7       |
# |    gen/time/fps                    | 1900        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 1           |
# |    gen/time/total_timesteps        | 18432       |
# |    gen/train/approx_kl             | 0.006229627 |
# |    gen/train/clip_fraction         | 0.413       |
# |    gen/train/clip_range            | 0.1         |
# |    gen/train/entropy_loss          | -0.824      |
# |    gen/train/explained_variance    | 0.95        |
# |    gen/train/learning_rate         | 0.0005      |
# |    gen/train/loss                  | 0.0421      |
# |    gen/train/n_updates             | 40          |
# |    gen/train/policy_gradient_loss  | -0.0278     |
# |    gen/train/value_loss            | 1.1         |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.773    |
# |    disc/disc_acc_expert             | 0.696    |
# |    disc/disc_acc_gen                | 0.85     |
# |    disc/disc_entropy                | 0.589    |
# |    disc/disc_loss                   | 0.518    |
# |    disc/disc_proportion_expert_pred | 0.423    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 9        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.78     |
# |    disc/disc_acc_expert             | 0.703    |
# |    disc/disc_acc_gen                | 0.857    |
# |    disc/disc_entropy                | 0.588    |
# |    disc/disc_loss                   | 0.513    |
# |    disc/disc_proportion_expert_pred | 0.423    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 9        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.761    |
# |    disc/disc_acc_expert             | 0.683    |
# |    disc/disc_acc_gen                | 0.84     |
# |    disc/disc_entropy                | 0.588    |
# |    disc/disc_loss                   | 0.524    |
# |    disc/disc_proportion_expert_pred | 0.421    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 9        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.773    |
# |    disc/disc_acc_expert             | 0.698    |
# |    disc/disc_acc_gen                | 0.848    |
# |    disc/disc_entropy                | 0.588    |
# |    disc/disc_loss                   | 0.515    |
# |    disc/disc_proportion_expert_pred | 0.425    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 9        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.771    |
# |    disc/disc_acc_expert             | 0.693    |
# |    disc/disc_acc_gen                | 0.85     |
# |    disc/disc_entropy                | 0.588    |
# |    disc/disc_loss                   | 0.519    |
# |    disc/disc_proportion_expert_pred | 0.421    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 9        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.779    |
# |    disc/disc_acc_expert             | 0.702    |
# |    disc/disc_acc_gen                | 0.855    |
# |    disc/disc_entropy                | 0.588    |
# |    disc/disc_loss                   | 0.512    |
# |    disc/disc_proportion_expert_pred | 0.424    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 9        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.759    |
# |    disc/disc_acc_expert             | 0.687    |
# |    disc/disc_acc_gen                | 0.832    |
# |    disc/disc_entropy                | 0.585    |
# |    disc/disc_loss                   | 0.521    |
# |    disc/disc_proportion_expert_pred | 0.428    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 9        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.772    |
# |    disc/disc_acc_expert             | 0.706    |
# |    disc/disc_acc_gen                | 0.839    |
# |    disc/disc_entropy                | 0.583    |
# |    disc/disc_loss                   | 0.512    |
# |    disc/disc_proportion_expert_pred | 0.433    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 9        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.775    |
# |    disc/disc_acc_expert             | 0.701    |
# |    disc/disc_acc_gen                | 0.849    |
# |    disc/disc_entropy                | 0.584    |
# |    disc/disc_loss                   | 0.509    |
# |    disc/disc_proportion_expert_pred | 0.426    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 9        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.771    |
# |    disc/disc_acc_expert             | 0.701    |
# |    disc/disc_acc_gen                | 0.841    |
# |    disc/disc_entropy                | 0.585    |
# |    disc/disc_loss                   | 0.511    |
# |    disc/disc_proportion_expert_pred | 0.43     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 9        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.766    |
# |    disc/disc_acc_expert             | 0.682    |
# |    disc/disc_acc_gen                | 0.851    |
# |    disc/disc_entropy                | 0.582    |
# |    disc/disc_loss                   | 0.512    |
# |    disc/disc_proportion_expert_pred | 0.416    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 9        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.766    |
# |    disc/disc_acc_expert             | 0.691    |
# |    disc/disc_acc_gen                | 0.842    |
# |    disc/disc_entropy                | 0.582    |
# |    disc/disc_loss                   | 0.51     |
# |    disc/disc_proportion_expert_pred | 0.425    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 9        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.773    |
# |    disc/disc_acc_expert             | 0.696    |
# |    disc/disc_acc_gen                | 0.851    |
# |    disc/disc_entropy                | 0.579    |
# |    disc/disc_loss                   | 0.504    |
# |    disc/disc_proportion_expert_pred | 0.423    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 9        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.765    |
# |    disc/disc_acc_expert             | 0.679    |
# |    disc/disc_acc_gen                | 0.851    |
# |    disc/disc_entropy                | 0.581    |
# |    disc/disc_loss                   | 0.512    |
# |    disc/disc_proportion_expert_pred | 0.414    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 9        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.766    |
# |    disc/disc_acc_expert             | 0.685    |
# |    disc/disc_acc_gen                | 0.847    |
# |    disc/disc_entropy                | 0.58     |
# |    disc/disc_loss                   | 0.51     |
# |    disc/disc_proportion_expert_pred | 0.419    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 9        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.769    |
# |    disc/disc_acc_expert             | 0.688    |
# |    disc/disc_acc_gen                | 0.85     |
# |    disc/disc_entropy                | 0.578    |
# |    disc/disc_loss                   | 0.505    |
# |    disc/disc_proportion_expert_pred | 0.419    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 9        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.77     |
# |    disc/disc_acc_expert             | 0.693    |
# |    disc/disc_acc_gen                | 0.847    |
# |    disc/disc_entropy                | 0.584    |
# |    disc/disc_loss                   | 0.513    |
# |    disc/disc_proportion_expert_pred | 0.423    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 9        |
# |    disc/n_expert                    | 2.05e+03 |
# |    disc/n_generated                 | 2.05e+03 |
# |    gen/rollout/ep_len_mean          | 26.2     |
# |    gen/rollout/ep_rew_mean          | 56.5     |
# |    gen/rollout/ep_rew_wrapped_mean  | -32.7    |
# |    gen/time/fps                     | 1.9e+03  |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 1        |
# |    gen/time/total_timesteps         | 1.84e+04 |
# |    gen/train/approx_kl              | 0.00887  |
# |    gen/train/clip_fraction          | 0.47     |
# |    gen/train/clip_range             | 0.1      |
# |    gen/train/entropy_loss           | -0.742   |
# |    gen/train/explained_variance     | 0.941    |
# |    gen/train/learning_rate          | 0.0005   |
# |    gen/train/loss                   | 0.152    |
# |    gen/train/n_updates              | 45       |
# |    gen/train/policy_gradient_loss   | -0.0292  |
# |    gen/train/value_loss             | 1.49     |
# --------------------------------------------------
# round: 100%|██████████| 9/9 [00:16<00:00,  1.83s/it]

# %%
# Helper function to calculate the behavorial cloning loss
def behavioral_cloning_loss(expert_trajs, learner_policy, device='cpu'):
    """
    Calculates the behavioral cloning loss (a measurement of policy similarity) by using
    expert trajectories and the learned policy from AIRL.
    :param options: A list of trajectories, and a learned policy
    :return: Behavorial cloning loss
    """
    total_loss = 0
    num_samples = 0

    for traj in expert_trajs:
        states = traj.obs  # Observations (states) from the trajectory
        expert_actions = traj.acts  # Expert's actions
        
        # Convert states to PyTorch Tensors
        states_tensor = th.tensor(states, dtype=th.float32, device=device)
        
        # Get learner's actions from the policy
        with th.no_grad():
            learner_actions = learner_policy(states_tensor)[0]

        learner_actions_np = learner_actions.cpu().numpy()
        
    #     # Calculate the loss (number of mismatched actions)
        loss = np.sum(learner_actions_np != expert_actions)
        total_loss += loss
        num_samples += len(states)

    return total_loss / num_samples  # Average loss

bc_loss = behavioral_cloning_loss(trajectories, learner.policy)
print(f"Behavioral Cloning Loss: {bc_loss}")
# Out:
# /var/folders/wp/q7yyy4ls2m3bvyscgh359t0r0000gn/T/ipykernel_7663/1225462061.py:19: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   loss = np.sum(learner_actions_np != expert_actions)
# Behavioral Cloning Loss: 0.022340377999195745
